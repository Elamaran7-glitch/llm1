# %%
import os
import pandas as pd
from pandasai import SmartDataframe
from langchain_google_vertexai import VertexAI

# %%
# Sample DataFrame
df = pd.read_csv('C:\\Users\\gopesh.r\\Downloads\\LLA-J\\Jamaica_partial_cleaned.csv')

# By default, unless you choose a different LLM, it will use BambooLLM.
# You can get your free API key signing up at https://pandabi.ai (you can also configure it in your .env file)
os.environ["PANDASAI_API_KEY"] = "$2a$10$M5KPk2dPSIJqtks/lnJE1uZaXPH7KNUvKN.GoC0xQSTDvVYkDimdy"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "C:\\Users\\gopesh.r\\Downloads\\LLA-J\\lumen-b-ctl-047-e2aeb24b0ea0.json"
llm = VertexAI(model_name='gemini-1.5-pro-preview-0409', temperature=0.5, max_output_tokens=8192)
# Output: China, United States, Japan, Germany, Australia

# %%
sdf = SmartDataframe(df, config={"llm": llm, "enable_cache": False})
# sdf.chat('Give me the analysis of prepaid churn in march month. Be descriptive. give a text response')

# %%
response = sdf.chat("give me for april now")

# %%
response = sdf.chat("Give me the analysis of postpaid churn in march month. Be descriptive. give a tabular response")
# Out:
# c:\Users\gopesh.r\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandasai\helpers\data_sampler.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sampled_df[col] = col_sample
# c:\Users\gopesh.r\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandasai\helpers\data_sampler.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sampled_df[col] = col_sample
# ...

# %%
result = sdf.last_code_executed

# %%
print(result)
# Out:
# df = dfs[0]
# df['Datetime'] = pd.to_datetime(df['Datetime'])
# march_df = df[df['Datetime'].dt.month == 3]
# postpaid_churn = march_df[['Datetime', 'Postpaid Churn']]
# fig, ax = plt.subplots(figsize=(10, 6))
# ax.plot(postpaid_churn['Datetime'], postpaid_churn['Postpaid Churn'])
# ax.set_xlabel('Date')
# ax.set_ylabel('Postpaid Churn')
# ax.set_title('Postpaid Churn in March')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.savefig('c:/Users/gopesh.r/Downloads/LLA-J/exports/charts/temp_chart.png')
# result = {'type': 'plot', 'value': 'c:/Users/gopesh.r/Downloads/LLA-J/exports/charts/temp_chart.png'}

# %%
import matplotlib.pyplot as plt

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'])
march_df = df[df['Datetime'].dt.month == 3]
postpaid_churn = march_df[['Datetime', 'Postpaid Churn']]
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(postpaid_churn['Datetime'], postpaid_churn['Postpaid Churn'])
ax.set_xlabel('Date')
ax.set_ylabel('Postpaid Churn')
ax.set_title('Postpaid Churn in March')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('c:/Users/gopesh.r/Downloads/LLA-J/exports/charts/temp_chart.png')
result = {'type': 'plot', 'value': 'c:/Users/gopesh.r/Downloads/LLA-J/exports/charts/temp_chart.png'}
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import json

# %%
print(result.split('\n')[::-1][0].split(' = ')[1])
json_result = result.split('\n')[::-1][0].split(' = ')[1].replace('\'', "\"")
# Out:
# {'type': 'dataframe', 'value': pd.DataFrame({'Analysis': ['Total Postpaid Churn in March'], 'Value': [postpaid_churn_march]})}

# %%
json_result
# Out:
# '{"type": "dataframe", "value": pd.DataFrame({"Analysis": ["Total Postpaid Churn in March"], "Value": [postpaid_churn_march]})}'

# %%
try:
    json_result = json.loads(json_result)
except:
    json_result = json_result.split(",")[0] + "}"
    json_result = json.loads(json_result)

# %%
# Out:
# 'dataframe'

# %%
response
# Out:
#      Datetime  Postpaid Churn
# 0  2024-03-01            -478
# 1  2024-03-02             -35
# 2  2024-03-03              -9
# 3  2024-03-04             -32
# 4  2024-03-05            -132
# 5  2024-03-06            -248
# 6  2024-03-07             -83
# 7  2024-03-08             -76
# 8  2024-03-09            -431
# 9  2024-03-10             -75
# 10 2024-03-11             -72
# 11 2024-03-12            -202
# 12 2024-03-13            -197
# 13 2024-03-14            -103
# 14 2024-03-15             -65
# 15 2024-03-16            -272
# 16 2024-03-17             -15
# 17 2024-03-18             -70
# 18 2024-03-19             -71
# 19 2024-03-20            -253
# 20 2024-03-21             -48
# 21 2024-03-22            -190
# 22 2024-03-23            -396
# 23 2024-03-24             -28
# 24 2024-03-25             -37
# 25 2024-03-26             -90
# 26 2024-03-27            -119
# 27 2024-03-28            -213
# 28 2024-03-29             -70
# 29 2024-03-30             -42
# ...

# %%
print(sdf.last_code_executed)
# Out:
# march_churn = dfs[0][dfs[0]['Datetime'].dt.month == 4]['Prepaid Churn'].sum()
# result = {'type': 'string', 'value': f'The total prepaid churn for the month of April is {march_churn}.'}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
